# %%
2 + 3 * 9
# Out:
# 29

# %% [markdown]
# Код выше написан на языке Python

# %%
pwd
# Out:
# '/content'

# %%
# !ls /
# Out:
# bin	 dev   lib32   mnt			 root  sys    var
# boot	 etc   lib64   NGC-DL-CONTAINER-LICENSE  run   tmp
# content  home  libx32  opt			 sbin  tools
# datalab  lib   media   proc			 srv   usr

# %% [markdown]
# # Настройка Git
# * настроим имя и email
# * получить токен от github

# %%
# !git config --global user.name "hkzalkash"
# !git config --global user.email "nolirow444@yahoo.com"

# %%
token = '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'
username = 'Padro97'
repo = 'Anonymous'

# %% [markdown]
# Перейдем в папку и подключимся к диску

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/Padro97/Anonymous.git
# Out:
# fatal: destination path 'Anonymous' already exists and is not an empty directory.

# %%
# !mv conspects_LysyakovAA.ipynb Anonymous/

# %%
cd /content/drive/MyDrive/Colab Notebooks/Anonymous
# Out:
# /content/drive/MyDrive/Colab Notebooks/Anonymous

# %% [markdown]
# # Математика Python
# * Какие математические операции можно проводить с числами в Pythom
# * Приведите примеры и найдите 3 отличия от классической математики.
# * Используйте ячейки кода и текста в Google Colab

# %%
4 + 32 * 3 - 1 / 4
# Out:
# 99.75

# %% [markdown]
# # Передадим файл  в репозиторий

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git add .

# %%
# !git status
# Out:
# On branch AALysyakov
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   conspects_LysyakovAA.ipynb

# %%
# !git commit -m 'добавил новый файл'
# Out:
# [AALysyakov 25a007c] добавил новый файл
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Padro97/Anonymous.git (fetch)
# origin	https://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@github.com/Padro97/Anonymous.git (push)

# %%
token = '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'
username = 'Padro97'
repo = 'Anonymous'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push origin AALysyakov
# Out:
# Enumerating objects: 31, done.
# Counting objects: 100% (31/31), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (30/30), done.
# Writing objects: 100% (30/30), 14.69 KiB | 294.00 KiB/s, done.
# Total 30 (delta 11), reused 0 (delta 0)
# remote: Resolving deltas: 100% (11/11), done.
# remote:
# remote: Create a pull request for 'AALysyakov' on GitHub by visiting:
# remote:      https://github.com/Padro97/Anonymous/pull/new/AALysyakov
# remote:
# To https://github.com/Padro97/Anonymous.git
#  * [new branch]      AALysyakov -> AALysyakov

# %%
# !git pull origin master
# Out:
# From https://github.com/Padro97/Anonymous
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !git branch
# Out:
# * AALysyakov
#   master

# %%
# !git checkout -b AALysyakov
# Out:
# Switched to a new branch 'AALysyakov'

# %% [markdown]
# # Домашнее задание
# # Задание 1
# В Python можно проводить следующие математические операции с числами:
#
# * сложение (+)
# * вычитание (-)
# * умножение (*)
# * деление (/)
# * деление по модулю (%), которое возвращает остаток от деления
# * возведение в степень (**)

# %% [markdown]
# ## Примеры

# %%
43 + 4 #Сложение
# Out:
# 47

# %%
444 - 12 #Вычитание
# Out:
# 432

# %%
43 * 32 #Умножение
# Out:
# 1376

# %%
24 / 24 #Деление
# Out:
# 1.0

# %%
14%3 #Деление с остатком
# Out:
# 2

# %%
32 ** 12 #Возведение в степень
# Out:
# 1152921504606846976

# %% [markdown]
# ## Задание 2
# Три отличия от классической математики:
#
# Python поддерживает работу с десятичными дробями, в то время как в классической математике это может быть недоступно.
# В Python есть возможность работы со встроенными комплексными числами, тогда как в классической математике комплексные числа не используются так часто.
# В Python результат деления двух целых чисел всегда является десятичной дробью, в то время как в классической математике результатом может быть целое число.
