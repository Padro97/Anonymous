# %%
2 + 3 * 9
# Out:
# 29

# %% [markdown]
# Код выше написан на языке Python

# %%
pwd
# Out:
# '/content'

# %%
# !ls /
# Out:
# bin	 dev   lib32   mnt			 root  sys    var
# boot	 etc   lib64   NGC-DL-CONTAINER-LICENSE  run   tmp
# content  home  libx32  opt			 sbin  tools
# datalab  lib   media   proc			 srv   usr

# %% [markdown]
# # Настройка Git
# * настроим имя и email
# * получить токен от github

# %%
# !git config --global user.name "hkzalkash"
# !git config --global user.email "nolirow444@yahoo.com"

# %%
token = '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'
username = 'Padro97'
repo = 'Anonymous'

# %% [markdown]
# Перейдем в папку и подключимся к диску

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/Padro97/Anonymous.git
# Out:
# fatal: destination path 'Anonymous' already exists and is not an empty directory.

# %%
# !mv conspects_LysyakovAA.ipynb Anonymous/

# %%
cd /content/drive/MyDrive/Colab Notebooks/Anonymous
# Out:
# /content/drive/MyDrive/Colab Notebooks/Anonymous

# %% [markdown]
# # Математика Python
# * Какие математические операции можно проводить с числами в Pythom
# * Приведите примеры и найдите 3 отличия от классической математики.
# * Используйте ячейки кода и текста в Google Colab

# %%
4 + 32 * 3 - 1 / 4
# Out:
# 99.75

# %% [markdown]
# # Передадим файл  в репозиторий

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   conspects_LysyakovAA.ipynb

# %%
# !git commit -m 'добавил новый файл'
# Out:
# [master 4654d8c] добавил новый файл
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Padro97/Anonymous.git (fetch)
# origin	https://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@github.com/Padro97/Anonymous.git (push)

# %%
token = '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'
username = 'Padro97'
repo = 'Anonymous'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push origin Lysyakov-AA
# Out:
# error: src refspec Lysyakov-AA does not match any
# error: failed to push some refs to 'https://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@github.com/Padro97/Anonymous.git'

# %%
# !git pull origin master
# Out:
# From https://github.com/Padro97/Anonymous
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !git branch
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git checkout AALysyakov
# Out:
# error: pathspec 'AALysyakov' did not match any file(s) known to git
